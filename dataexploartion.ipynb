# %% [markdown]
# <a href="https://colab.research.google.com/github/vedashree-m/classwork-and-assignments/blob/main/dataexploartion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

path='/content/drive/MyDrive/Food_Time_Data_Set.csv'
mydata=pd.read_csv(path)
mydata.head()
# Out:
#      ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  4607     INDORES13DEL02                 37.0                      4.9
# 1  B379     BANGRES18DEL02                 34.0                      4.5
# 2  5D6D     BANGRES19DEL01                 23.0                      4.4
# 3  7A6A    COIMBRES13DEL02                 38.0                      4.7
# 4  70A2     CHENRES12DEL01                 32.0                      4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            22.745049             75.892471                   22.765049
# 1            12.913041             77.683237                   13.043041
# 2            12.914264             77.678400                   12.924264
# 3            11.003669             76.976494                   11.053669
# 4            12.972793             80.249982                   13.012793
#
#    Delivery_location_longitude Type_of_order Type_of_vehicle  temperature  \
# ...

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10001 entries, 0 to 10000
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           10000 non-null  object
#  1   Delivery_person_ID           10000 non-null  object
#  2   Delivery_person_Age          10000 non-null  float64
#  3   Delivery_person_Ratings      10000 non-null  float64
#  4   Restaurant_latitude          10000 non-null  float64
#  5   Restaurant_longitude         10000 non-null  float64
#  6   Delivery_location_latitude   10000 non-null  float64
#  7   Delivery_location_longitude  10000 non-null  float64
#  8   Type_of_order                10000 non-null  object
#  9   Type_of_vehicle              10000 non-null  object
#  10  temperature                  9995 non-null   float64
#  11  humidity                     9995 non-null   float64
# ...

# %% [markdown]
# there are 1000 entries , and this data contains 17 interesting features. it also contains some null values in some featues like unnamed:14 .

# %%
mydata.tail()
# Out:
#          ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 9996   11B4      VADRES13DEL03                 32.0                      4.2
# 9997   8336      HYDRES20DEL01                 36.0                      4.7
# 9998   338B      JAPRES18DEL03                 37.0                      4.6
# 9999   3FB2      MUMRES11DEL03                 29.0                      4.7
# 10000   NaN                NaN                  NaN                      NaN
#
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 9996             22.310237             73.158921                   22.400237
# 9997             17.483216             78.552111                   17.493216
# 9998             26.913987             75.752891                   27.053987
# 9999             18.994237             72.825553                   19.084237
# 10000                  NaN                   NaN                         NaN
#
# ...

# %%
print(mydata["Delivery_person_ID"].value_counts())
# Out:
# Delivery_person_ID
# SURRES16DEL01       22
# CHENRES01DEL02      22
# RANCHIRES18DEL01    22
# COIMBRES06DEL01     22
# COIMBRES03DEL02     20
#                     ..
# DEHRES16DEL01        1
# AURGRES13DEL03       1
# KNPRES08DEL03        1
# BHPRES17DEL01        1
# ALHRES13DEL01        1
# Name: count, Length: 1285, dtype: int64

# %%
print(mydata["humidity"].value_counts())
# Out:
# humidity
# 73.0    1033
# 65.0     617
# 82.0     604
# 60.0     553
# 43.0     526
#         ...
# 62.0       8
# 27.0       8
# 30.0       8
# 32.0       6
# 31.0       5
# Name: count, Length: 64, dtype: int64

# %%
mydata.plot(kind='scatter' ,x="Delivery_person_Age",y="Delivery_person_Ratings",grid=True)
# Out:
# <Axes: xlabel='Delivery_person_Age', ylabel='Delivery_person_Ratings'>

# %%
mydata.hist(bins=50, figsize=(12,6))
# Out:
# array([[<Axes: title={'center': 'Delivery_person_Age'}>,
#         <Axes: title={'center': 'Delivery_person_Ratings'}>,
#         <Axes: title={'center': 'Restaurant_latitude'}>],
#        [<Axes: title={'center': 'Restaurant_longitude'}>,
#         <Axes: title={'center': 'Delivery_location_latitude'}>,
#         <Axes: title={'center': 'Delivery_location_longitude'}>],
#        [<Axes: title={'center': 'temperature'}>,
#         <Axes: title={'center': 'humidity'}>,
#         <Axes: title={'center': 'precipitation'}>],
#        [<Axes: title={'center': 'Unnamed: 14'}>,
#         <Axes: title={'center': 'Distance (km)'}>, <Axes: >]],
#       dtype=object)

# %%
null_rows_idx=mydata.isnull().any(axis=1)
mydata.loc[null_rows_idx]
# Out:
#          ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0      4607     INDORES13DEL02                 37.0                      4.9
# 1      B379     BANGRES18DEL02                 34.0                      4.5
# 2      5D6D     BANGRES19DEL01                 23.0                      4.4
# 3      7A6A    COIMBRES13DEL02                 38.0                      4.7
# 4      70A2     CHENRES12DEL01                 32.0                      4.6
# ...     ...                ...                  ...                      ...
# 9996   11B4      VADRES13DEL03                 32.0                      4.2
# 9997   8336      HYDRES20DEL01                 36.0                      4.7
# 9998   338B      JAPRES18DEL03                 37.0                      4.6
# 9999   3FB2      MUMRES11DEL03                 29.0                      4.7
# 10000   NaN                NaN                  NaN                      NaN
#
# ...

# %%
duplicates=mydata.duplicated()
print(duplicates)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 9996     False
# 9997     False
# 9998     False
# 9999     False
# 10000    False
# Length: 10001, dtype: bool

# %%
duplicates=mydata[mydata.duplicated(subset=['Delivery_person_ID'])]
print(duplicates)
# Out:
#         ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 34    30C8     PUNERES19DEL02                 32.0                      4.6
# 48    A30B     CHENRES11DEL01                 37.0                      4.8
# 50    5554   RANCHIRES15DEL01                 31.0                      4.9
# 51    25FD     BANGRES19DEL01                 31.0                      4.8
# 64    1609     PUNERES02DEL01                 36.0                      4.9
# ...    ...                ...                  ...                      ...
# 9995  4347      MUMRES07DEL01                 25.0                      4.0
# 9996  11B4      VADRES13DEL03                 32.0                      4.2
# 9997  8336      HYDRES20DEL01                 36.0                      4.7
# 9998  338B      JAPRES18DEL03                 37.0                      4.6
# 9999  3FB2      MUMRES11DEL03                 29.0                      4.7
#
# ...

# %%
mydata.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 9996     False
# 9997     False
# 9998     False
# 9999     False
# 10000    False
# Length: 10001, dtype: bool

# %%
mydata["Delivery_person_ID"].value_counts()
# Out:
# Delivery_person_ID
# SURRES16DEL01       22
# CHENRES01DEL02      22
# RANCHIRES18DEL01    22
# COIMBRES06DEL01     22
# COIMBRES03DEL02     20
#                     ..
# DEHRES16DEL01        1
# AURGRES13DEL03       1
# KNPRES08DEL03        1
# BHPRES17DEL01        1
# ALHRES13DEL01        1
# Name: count, Length: 1285, dtype: int64

# %%
mydata.isnull()
# Out:
#           ID  Delivery_person_ID  Delivery_person_Age  \
# 0      False               False                False
# 1      False               False                False
# 2      False               False                False
# 3      False               False                False
# 4      False               False                False
# ...      ...                 ...                  ...
# 9996   False               False                False
# 9997   False               False                False
# 9998   False               False                False
# 9999   False               False                False
# 10000   True                True                 True
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 0                        False                False                 False
# 1                        False                False                 False
# 2                        False                False                 False
# ...

# %%
mydata.describe()
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# count         10000.000000             10000.000000         10000.000000
# mean             29.522000                 4.629370            16.893418
# std               5.700348                 0.322941             8.330948
# min              15.000000                 1.000000           -30.902872
# 25%              25.000000                 4.500000            12.913041
# 50%              29.000000                 4.700000            18.546258
# 75%              34.000000                 4.800000            22.727021
# max              50.000000                 6.000000            30.914057
#
#        Restaurant_longitude  Delivery_location_latitude  \
# count          10000.000000                10000.000000
# mean              70.177749                   17.412655
# std               23.203352                    7.336846
# min              -88.352885                    0.010000
# ...

# %%
mydata.duplicated().value_counts()
# Out:
# False    10001
# Name: count, dtype: int64

# %%
mydata.hist(bins=50, figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'Delivery_person_Age'}>,
#         <Axes: title={'center': 'Delivery_person_Ratings'}>,
#         <Axes: title={'center': 'Restaurant_latitude'}>],
#        [<Axes: title={'center': 'Restaurant_longitude'}>,
#         <Axes: title={'center': 'Delivery_location_latitude'}>,
#         <Axes: title={'center': 'Delivery_location_longitude'}>],
#        [<Axes: title={'center': 'temperature'}>,
#         <Axes: title={'center': 'humidity'}>,
#         <Axes: title={'center': 'precipitation'}>],
#        [<Axes: title={'center': 'Unnamed: 14'}>,
#         <Axes: title={'center': 'Distance (km)'}>, <Axes: >]],
#       dtype=object)
